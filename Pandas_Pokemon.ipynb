# %% [markdown]
# <a href="https://colab.research.google.com/github/codeplinth/pandasbootcamp/blob/master/Pandas_Pokemon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls "/content/drive/My Drive/data"
# Out:
#  bigmac.csv			    fortune1000.csv
#  chicago.csv			    google_stock_price.csv
#  data.csv			    houseprice.csv
# 'Data - Multiple Worksheets.xlsx'   IMDB-Movie-Data.csv
# 'Data - Single Worksheet.xlsx'	    index.csv
#  diabetes.csv			    jamesbond.csv
#  ecommerce.csv			    lang.csv
#  employees.csv			    nba.csv
#  foods.csv			    pokemon.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/My Drive/data/pokemon.csv')

# %%
df.head()
# Out:
#    #                   Name Type 1  ... Speed  Generation  Legendary
# 0  1              Bulbasaur  Grass  ...    45           1      False
# 1  2                Ivysaur  Grass  ...    60           1      False
# 2  3               Venusaur  Grass  ...    80           1      False
# 3  3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 4  4             Charmander   Fire  ...    65           1      False
#
# [5 rows x 12 columns]

# %%
df.tail(3)
# Out:
#        #                 Name   Type 1  ... Speed  Generation  Legendary
# 797  720  HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720   HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721            Volcanion     Fire  ...    70           6       True
#
# [3 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df['Name']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
df[['Name','Generation','Speed']]
# Out:
#                       Name  Generation  Speed
# 0                Bulbasaur           1     45
# 1                  Ivysaur           1     60
# 2                 Venusaur           1     80
# 3    VenusaurMega Venusaur           1     80
# 4               Charmander           1     65
# ..                     ...         ...    ...
# 795                Diancie           6     50
# 796    DiancieMega Diancie           6    110
# 797    HoopaHoopa Confined           6     70
# 798     HoopaHoopa Unbound           6     80
# 799              Volcanion           6     70
#
# [800 rows x 3 columns]

# %%
df.describe()
# Out:
#                 #          HP      Attack  ...     Sp. Def       Speed  Generation
# count  800.000000  800.000000  800.000000  ...  800.000000  800.000000   800.00000
# mean   362.813750   69.258750   79.001250  ...   71.902500   68.277500     3.32375
# std    208.343798   25.534669   32.457366  ...   27.828916   29.060474     1.66129
# min      1.000000    1.000000    5.000000  ...   20.000000    5.000000     1.00000
# 25%    184.750000   50.000000   55.000000  ...   50.000000   45.000000     2.00000
# 50%    364.500000   65.000000   75.000000  ...   70.000000   65.000000     3.00000
# 75%    539.250000   80.000000  100.000000  ...   90.000000   90.000000     5.00000
# max    721.000000  255.000000  190.000000  ...  230.000000  180.000000     6.00000
#
# [8 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
df.iloc[0:4]
# Out:
#    #                   Name Type 1  ... Speed  Generation  Legendary
# 0  1              Bulbasaur  Grass  ...    45           1      False
# 1  2                Ivysaur  Grass  ...    60           1      False
# 2  3               Venusaur  Grass  ...    80           1      False
# 3  3  VenusaurMega Venusaur  Grass  ...    80           1      False
#
# [4 rows x 12 columns]

# %%
df.iloc[2,1]
# Out:
# 'Venusaur'

# %%
df.loc[df['Type 1'] == 'Grass']
# Out:
#        #                   Name Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur  Grass  ...    45           1      False
# 1      2                Ivysaur  Grass  ...    60           1      False
# 2      3               Venusaur  Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 48    43                 Oddish  Grass  ...    30           1      False
# ..   ...                    ...    ...  ...   ...         ...        ...
# 718  650                Chespin  Grass  ...    38           6      False
# 719  651              Quilladin  Grass  ...    57           6      False
# 720  652             Chesnaught  Grass  ...    64           6      False
# 740  672                 Skiddo  Grass  ...    52           6      False
# 741  673                 Gogoat  Grass  ...    68           6      False
#
# [70 rows x 12 columns]

# %%
df.sort_values(['Type 1','Name'])
# Out:
#        #                   Name Type 1  ... Speed  Generation  Legendary
# 678  617               Accelgor    Bug  ...   145           5      False
# 182  168                Ariados    Bug  ...    40           2      False
# 290  267              Beautifly    Bug  ...    65           3      False
# 18    15               Beedrill    Bug  ...    75           1      False
# 19    15  BeedrillMega Beedrill    Bug  ...   145           1      False
# ..   ...                    ...    ...  ...   ...         ...        ...
# 351  321                Wailord  Water  ...    60           3      False
# 10     8              Wartortle  Water  ...    58           1      False
# 372  340               Whiscash  Water  ...    60           3      False
# 301  278                Wingull  Water  ...    85           3      False
# 209  194                 Wooper  Water  ...    15           2      False
#
# [800 rows x 12 columns]

# %%
df.iloc[0,6]
# Out:
# 49

# %%
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

# %%
df
# Out:
#        #                   Name   Type 1  ... Generation  Legendary  Total
# 0      1              Bulbasaur    Grass  ...          1      False    318
# 1      2                Ivysaur    Grass  ...          1      False    405
# 2      3               Venusaur    Grass  ...          1      False    525
# 3      3  VenusaurMega Venusaur    Grass  ...          1      False    625
# 4      4             Charmander     Fire  ...          1      False    309
# ..   ...                    ...      ...  ...        ...        ...    ...
# 795  719                Diancie     Rock  ...          6       True    600
# 796  719    DiancieMega Diancie     Rock  ...          6       True    700
# 797  720    HoopaHoopa Confined  Psychic  ...          6       True    600
# 798  720     HoopaHoopa Unbound  Psychic  ...          6       True    680
# 799  721              Volcanion     Fire  ...          6       True    600
#
# [800 rows x 13 columns]

# %%
df =  df.drop(columns=['Total'])

# %%
df
# Out:
#        #                   Name   Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur    Grass  ...    45           1      False
# 1      2                Ivysaur    Grass  ...    60           1      False
# 2      3               Venusaur    Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur    Grass  ...    80           1      False
# 4      4             Charmander     Fire  ...    65           1      False
# ..   ...                    ...      ...  ...   ...         ...        ...
# 795  719                Diancie     Rock  ...    50           6       True
# 796  719    DiancieMega Diancie     Rock  ...   110           6       True
# 797  720    HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720     HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721              Volcanion     Fire  ...    70           6       True
#
# [800 rows x 12 columns]

# %%
df['Total'] = df.iloc[:,4:10].sum(axis=1)

# %%
df
# Out:
#        #                   Name   Type 1  ... Generation  Legendary  Total
# 0      1              Bulbasaur    Grass  ...          1      False    318
# 1      2                Ivysaur    Grass  ...          1      False    405
# 2      3               Venusaur    Grass  ...          1      False    525
# 3      3  VenusaurMega Venusaur    Grass  ...          1      False    625
# 4      4             Charmander     Fire  ...          1      False    309
# ..   ...                    ...      ...  ...        ...        ...    ...
# 795  719                Diancie     Rock  ...          6       True    600
# 796  719    DiancieMega Diancie     Rock  ...          6       True    700
# 797  720    HoopaHoopa Confined  Psychic  ...          6       True    600
# 798  720     HoopaHoopa Unbound  Psychic  ...          6       True    680
# 799  721              Volcanion     Fire  ...          6       True    600
#
# [800 rows x 13 columns]

# %%
df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison')]
# Out:
#        #                   Name Type 1  ... Generation  Legendary  Total
# 0      1              Bulbasaur  Grass  ...          1      False    318
# 1      2                Ivysaur  Grass  ...          1      False    405
# 2      3               Venusaur  Grass  ...          1      False    525
# 3      3  VenusaurMega Venusaur  Grass  ...          1      False    625
# 48    43                 Oddish  Grass  ...          1      False    320
# 49    44                  Gloom  Grass  ...          1      False    395
# 50    45              Vileplume  Grass  ...          1      False    490
# 75    69             Bellsprout  Grass  ...          1      False    300
# 76    70             Weepinbell  Grass  ...          1      False    390
# 77    71             Victreebel  Grass  ...          1      False    490
# 344  315                Roselia  Grass  ...          3      False    400
# 451  406                  Budew  Grass  ...          4      False    280
# ...

# %%
df.loc[(df['Type 1'] == 'Grass') | (df['Type 2'] == 'Poison')]
# Out:
#        #                   Name Type 1  ... Generation  Legendary  Total
# 0      1              Bulbasaur  Grass  ...          1      False    318
# 1      2                Ivysaur  Grass  ...          1      False    405
# 2      3               Venusaur  Grass  ...          1      False    525
# 3      3  VenusaurMega Venusaur  Grass  ...          1      False    625
# 16    13                 Weedle    Bug  ...          1      False    195
# ..   ...                    ...    ...  ...        ...        ...    ...
# 718  650                Chespin  Grass  ...          6      False    313
# 719  651              Quilladin  Grass  ...          6      False    405
# 720  652             Chesnaught  Grass  ...          6      False    530
# 740  672                 Skiddo  Grass  ...          6      False    350
# 741  673                 Gogoat  Grass  ...          6      False    531
#
# [89 rows x 13 columns]

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]

# %%
new_df
# Out:
#        #                   Name Type 1  ... Generation  Legendary  Total
# 2      3               Venusaur  Grass  ...          1      False    525
# 3      3  VenusaurMega Venusaur  Grass  ...          1      False    625
# 50    45              Vileplume  Grass  ...          1      False    490
# 77    71             Victreebel  Grass  ...          1      False    490
# 652  591              Amoonguss  Grass  ...          5      False    464
#
# [5 rows x 13 columns]

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]
new_df.reset_index(drop=True,inplace=True)
new_df
# Out:
#      #                   Name Type 1  ... Generation  Legendary  Total
# 0    3               Venusaur  Grass  ...          1      False    525
# 1    3  VenusaurMega Venusaur  Grass  ...          1      False    625
# 2   45              Vileplume  Grass  ...          1      False    490
# 3   71             Victreebel  Grass  ...          1      False    490
# 4  591              Amoonguss  Grass  ...          5      False    464
#
# [5 rows x 13 columns]

# %%
df.loc[df['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1  ... Generation  Legendary  Total
# 3      3      VenusaurMega Venusaur     Grass  ...          1      False    625
# 7      6  CharizardMega Charizard X      Fire  ...          1      False    634
# 8      6  CharizardMega Charizard Y      Fire  ...          1      False    634
# 12     9    BlastoiseMega Blastoise     Water  ...          1      False    630
# 19    15      BeedrillMega Beedrill       Bug  ...          1      False    495
# 23    18        PidgeotMega Pidgeot    Normal  ...          1      False    579
# 71    65      AlakazamMega Alakazam   Psychic  ...          1      False    590
# 87    80        SlowbroMega Slowbro     Water  ...          1      False    590
# 102   94          GengarMega Gengar     Ghost  ...          1      False    600
# 124  115  KangaskhanMega Kangaskhan    Normal  ...          1      False    590
# 137  127          PinsirMega Pinsir       Bug  ...          1      False    600
# ...

# %%
df.loc[~df['Name'].str.contains('Mega')]
# Out:
#        #                 Name   Type 1  ... Generation  Legendary  Total
# 0      1            Bulbasaur    Grass  ...          1      False    318
# 1      2              Ivysaur    Grass  ...          1      False    405
# 2      3             Venusaur    Grass  ...          1      False    525
# 4      4           Charmander     Fire  ...          1      False    309
# 5      5           Charmeleon     Fire  ...          1      False    405
# ..   ...                  ...      ...  ...        ...        ...    ...
# 794  718     Zygarde50% Forme   Dragon  ...          6       True    600
# 795  719              Diancie     Rock  ...          6       True    600
# 797  720  HoopaHoopa Confined  Psychic  ...          6       True    600
# 798  720   HoopaHoopa Unbound  Psychic  ...          6       True    680
# 799  721            Volcanion     Fire  ...          6       True    600
#
# [751 rows x 13 columns]

# %%
import re

# %%
df.loc[df['Type 1'].str.contains('fire|grass',flags = re.I,regex=True)]
# Out:
#        #                   Name Type 1  ... Generation  Legendary  Total
# 0      1              Bulbasaur  Grass  ...          1      False    318
# 1      2                Ivysaur  Grass  ...          1      False    405
# 2      3               Venusaur  Grass  ...          1      False    525
# 3      3  VenusaurMega Venusaur  Grass  ...          1      False    625
# 4      4             Charmander   Fire  ...          1      False    309
# ..   ...                    ...    ...  ...        ...        ...    ...
# 735  667                 Litleo   Fire  ...          6      False    369
# 736  668                 Pyroar   Fire  ...          6      False    507
# 740  672                 Skiddo  Grass  ...          6      False    350
# 741  673                 Gogoat  Grass  ...          6      False    531
# 799  721              Volcanion   Fire  ...          6       True    600
#
# [122 rows x 13 columns]

# %%
df.loc[df['Name'].str.contains('^pi[a-z]*',flags = re.I,regex=True)]
# Out:
#        #                 Name    Type 1  ... Generation  Legendary  Total
# 20    16               Pidgey    Normal  ...          1      False    251
# 21    17            Pidgeotto    Normal  ...          1      False    349
# 22    18              Pidgeot    Normal  ...          1      False    479
# 23    18  PidgeotMega Pidgeot    Normal  ...          1      False    579
# 30    25              Pikachu  Electric  ...          1      False    320
# 136  127               Pinsir       Bug  ...          1      False    500
# 137  127    PinsirMega Pinsir       Bug  ...          1      False    600
# 186  172                Pichu  Electric  ...          2      False    205
# 219  204               Pineco       Bug  ...          2      False    290
# 239  221            Piloswine       Ice  ...          2      False    450
# 438  393               Piplup     Water  ...          4      False    314
# 558  499              Pignite      Fire  ...          5      False    418
# ...

# %%
df.loc[df['Type 1'] == 'Fire','Type 1'] = 'Flamer'
df
# Out:
#        #                   Name   Type 1  ... Generation  Legendary  Total
# 0      1              Bulbasaur    Grass  ...          1      False    318
# 1      2                Ivysaur    Grass  ...          1      False    405
# 2      3               Venusaur    Grass  ...          1      False    525
# 3      3  VenusaurMega Venusaur    Grass  ...          1      False    625
# 4      4             Charmander   Flamer  ...          1      False    309
# ..   ...                    ...      ...  ...        ...        ...    ...
# 795  719                Diancie     Rock  ...          6       True    600
# 796  719    DiancieMega Diancie     Rock  ...          6       True    700
# 797  720    HoopaHoopa Confined  Psychic  ...          6       True    600
# 798  720     HoopaHoopa Unbound  Psychic  ...          6       True    680
# 799  721              Volcanion   Flamer  ...          6       True    600
#
# [800 rows x 13 columns]

# %%
df.loc[df['Type 1'] == 'Flamer','Type 1'] = 'Fire'
df
# Out:
#        #                   Name   Type 1  ... Generation  Legendary  Total
# 0      1              Bulbasaur    Grass  ...          1      False    318
# 1      2                Ivysaur    Grass  ...          1      False    405
# 2      3               Venusaur    Grass  ...          1      False    525
# 3      3  VenusaurMega Venusaur    Grass  ...          1      False    625
# 4      4             Charmander     Fire  ...          1      False    309
# ..   ...                    ...      ...  ...        ...        ...    ...
# 795  719                Diancie     Rock  ...          6       True    600
# 796  719    DiancieMega Diancie     Rock  ...          6       True    700
# 797  720    HoopaHoopa Confined  Psychic  ...          6       True    600
# 798  720     HoopaHoopa Unbound  Psychic  ...          6       True    680
# 799  721              Volcanion     Fire  ...          6       True    600
#
# [800 rows x 13 columns]

# %%
df.groupby(['Type 1']).mean().sort_values('Defense',ascending=False)
# Out:
#                    #         HP      Attack  ...  Generation  Legendary       Total
# Type 1                                       ...
# Steel     442.851852  65.222222   92.703704  ...    3.851852   0.148148  487.703704
# Rock      392.727273  65.363636   92.863636  ...    3.454545   0.090909  453.750000
# Dragon    474.375000  83.312500  112.125000  ...    3.875000   0.375000  550.531250
# Ground    356.281250  73.781250   95.750000  ...    3.156250   0.125000  437.500000
# Ghost     486.500000  64.437500   73.781250  ...    4.187500   0.062500  439.562500
# Water     303.089286  72.062500   74.151786  ...    2.857143   0.035714  430.455357
# Ice       423.541667  72.000000   72.750000  ...    3.541667   0.083333  433.458333
# Grass     344.871429  67.271429   73.214286  ...    3.357143   0.042857  421.142857
# Bug       334.492754  56.884058   70.971014  ...    3.217391   0.000000  378.927536
# Dark      461.354839  66.806452   88.387097  ...    4.032258   0.064516  445.741935
# ...

# %%
df['count'] = 1
df.groupby(['Type 1']).count()['count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %%
df.groupby(['Type 1','Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64
